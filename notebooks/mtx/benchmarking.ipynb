# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ns_day = np.array([
    [5, 18.084, 17.3],
    [10, 24.895, 25.3],
    [15, 37.726, 27.0],
    [20, 78.422, 78.6],
    [25, 95.431, 95.8],
    [30, 53.461, 84.9],
    [35, 94.4, 94.6],
    [40, 111.05, 75.6],
    [45, 45.6, 113],
])
plt.title("performance in function of the number of cores, at 30 GB of ram")
plt.xlabel("number of cores")
plt.ylabel("ns / day")
plt.plot(ns_day[:, 0], ns_day[:, 1], label = "try 1")
plt.plot(ns_day[:, 0], ns_day[:, 2], label = "try 2")
plt.legend()

# %%
ns_day = np.array([
    [20,91.7],
    [30,73.6],
    [40,81.5]
])
plt.title("performance in function of the ram, at 25 cores")
plt.xlabel("ram [GB]")
plt.ylabel("ns / day")
plt.plot(ns_day[:, 0], ns_day[:, 1])
