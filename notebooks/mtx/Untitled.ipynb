# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
blocking_path = "/home/giacomo/comp_bio/cbp_final/data_3eig/02_processed/02_npt/prod_6/errest.xvg"

blocking = np.loadtxt(blocking_path, comments = ["#", "@"], delimiter = " ", max_rows = 103)
plt.plot(blocking[:, 2], blocking[:, 1])
# Out:
# /tmp/ipykernel_10630/4284438031.py:3: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=103`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   blocking = np.loadtxt(blocking_path, comments = ["#", "@"], delimiter = " ", max_rows = 103)

# %%
autocorr_path = "/home/giacomo/comp_bio/cbp_final/data_3eig/02_processed/02_npt/prod_6/autocorr.xvg"

autocorr = np.loadtxt(autocorr_path, comments = ["#", "@"], max_rows = 25000)
plt.plot(autocorr[:, 0], autocorr[:, 1])
plt.ylim([0, 0.1])
# Out:
# /tmp/ipykernel_10630/3176180248.py:3: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=25000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   autocorr = np.loadtxt(autocorr_path, comments = ["#", "@"], max_rows = 25000)
# (0.0, 0.1)
